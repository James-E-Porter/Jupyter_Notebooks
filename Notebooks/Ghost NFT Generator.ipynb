# %%
#  SCi fi NFT image and json creator.  This will run the creator 10 times.

import os
import json
import random
import openai
import ipfshttpclient
from PIL import Image, ImageDraw
import requests
from io import BytesIO
import time

openai.api_key = "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"

series_data = input("Enter the series data for your NFT: ")
description = input("Enter a description for your NFT: ")
asset_cid = input("Enter the IPFS CID for your NFT asset: ")
quantity = input("Enter the quantity you want to make: ")


if not os.path.exists('images'):
    os.makedirs('images')

if not os.path.exists('metadata'):
    os.makedirs('metadata')
    
    
def random_element(elements, rarity):
    if random.random() <= rarity / 100:
        return random.choice(elements)
    else:
        return None

def save_image(image_url, image_path):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    image.save(image_path)

def generate_scifi_name():
    syllables = ["al", "ar", "ba", "be", "ca", "ce", "da", "de", "el", "en", "fa", "fi", "fo", "ga", "gi", "he", "ho", "in", "io", "ja", "jo", "ka", "ki", "la", "le", "ma", "mi", "na", "nu", "ol", "or", "pa", "po", "qu", "ra", "re", "sa", "ta", "ul", "ve", "va", "we", "xo", "xi", "ye", "yo", "ze", "za"]
    name_length = random.randint(2, 4)
    name = ''
    
    for i in range(name_length):
        name += random.choice(syllables)
        
    return name.capitalize()

def random_nft_name():
    adjectives = ["Phantom", "Haunted", "Spectral", "Eerie", "Mysterious", "Spooky", "Creepy", "Unseen", "Wraithlike", "Shadowy", "Transparent", "Otherworldly", "Ghostly", "Supernatural", "Ethereal", "Uncanny", "Demonic", "Poltergeist", "Apparitional", "Cursed"]
    nouns = ["Spirit", "Phantom", "Specter", "Apparition", "Wraith", "Shade", "Banshee", "Poltergeist", "Demon", "Ghost", "Haunt", "Spook", "Entity", "Soul", "Presence", "Ectoplasm", "Manifestation", "Shadow", "Lost Soul", "Restless Spirit"]
    name = generate_scifi_name()
    return f'{random.choice(adjectives)} {random.choice(nouns)} {name}'
    
def generate_nft_character():
    base_prompt = 'hyper-realistic image of sci-fi girl in dramatic action pose with cyber tones'
    hair = ["Short and spiky", "Cropped and neat", "Chin-length bob", "Long and straight", "Curly and voluminous", "Wavy and shoulder-length", "Pixie cut", "Shaved sides with long top", "Sleek ponytail", "Messy bun", "Half-up half-down", "Braided crown", "French braid", "Cornrows", "Dreadlocks", "Fishtail braid", "Top knot", "Ballerina bun", "Braid-out", "Afro"]
    ghostly_clothing_styles = ["Victorian mourning attire", "Roaring 20s flapper dress", "Medieval knight's armor", "Ancient Roman toga", "1960s mod fashion", "1940s pin-up girl style", "1980s punk rock", "Gothic and Victorian Lolita fashion", "1960s hippie fashion", "1950s Greaser style", "1920s Great Gatsby attire", "1970s disco fashion", "Steampunk fashion", "Renaissance faire garb", "1920s Art Deco fashion", "Pirate attire", "Ninja or Samurai armor", "1960s beachwear", "1970s bohemian style", "1980s new wave fashion", "Futuristic and cybergoth fashion", "Edwardian era fashion", "Colonial or Revolutionary War-era attire", "Regency-era clothing", "Tudor-era clothing"]
    animals = ["Vampire bat", "Black widow spider", "Giant centipede", "Gila monster", "Deathstalker scorpion", "Horned lizard", "Electric eel", "Poison dart frog", "Hooded seal", "Komodo dragon", "Aye-aye", "Thorny devil", "Mexican red-knee tarantula", "Brown recluse spider", "Giant huntsman spider", "Boomslang snake", "Cave spider", "Redback spider", "Honey badger", "Monitor lizard"]
    color = ["beige", "cream", "off-white", "ivory", "champagne", "peach", "coral", "salmon", "pink", "rose", "lavender", "lilac", "mauve", "violet", "purple", "plum", "indigo", "navy", "teal", "turquoise", "sky blue", "baby blue", "cornflower blue", "royal blue", "cobalt blue", "navy blue", "steel blue", "mint green", "sage green", "olive green", "emerald green", "lime green", "forest green", "khaki", "camel", "goldenrod", "mustard", "ochre", "burnt orange", "rust", "terracotta", "brick red", "burgundy", "maroon", "taupe", "gray", "charcoal", "black", "white"]
    persona = ["Spirits", "Phantoms", "Apparitions", "Wraiths", "Shades", "Banshees", "Poltergeists", "Demons", "Ghosts", "Haunts", "Spooks", "Entities", "Souls", "Ectoplasms", "Manifestations", "Shadows", "Lost souls", "Restless spirits", "Ghostly soldiers", "Ghostly pilots", "Ghostly waifus", "Ghostly street urchins", "Ghostly punks", "Ghostly pirates", "Ghostly villainesses", "Ghostly villains", "Ghostly wizards", "Ghostly sorcerers", "Ghostly psychics", "Ghostly androids", "Ghostly psi-ops", "Ghostly assassins", "Ghostly divas", "Ghostly princesses", "Ghostly citizens", "Ghostly hooligans"]
    supernatural_highlights = ["Psychic visions", "Telepathic communication", "Mediumship", "Channeling spirits", "Divination", "Tarot reading", "Ouija board communication", "Spiritual healing", "Chakra cleansing", "Aura reading", "Past life regression", "Reiki energy healing", "Ghostly visitations", "Spiritual possession", "Supernatural levitation", "Poltergeist activity", "Spiritual apparitions", "Hauntings", "Exorcisms", "Cleansing rituals", "Séances", "Spiritual mediumship", "Intuition development", "Dream interpretation", "Spiritual ascension"]
    ghostly_glamor = ["Ethereal fashion accessories", "Spectral hairstyles and hair accessories", "Glow-in-the-dark jewelry", "Elaborate ghostly makeup", "Phantasmal lighting for home decor", "Haunting transportation options", "Ghostly tattoos and temporary body art", "Spectral fabrics and textiles", "Supernatural nail art", "Otherworldly prosthetics and cosmetic enhancements", "Incredible spectral special effects for personal photography or videography", "Ghostly home decor and furniture", "Apparitional bioluminescent flora for indoor gardens", "Ethereal pet accessories", "Spectral party decorations", "Supernatural gadgets for personal use", "Spectral accessories for themed events or performances"]
    spooky_background = ["Abandoned haunted mansion", "Gothic castle", "Dreary graveyard", "Creepy forest at night", "Dark and shadowy alleyway", "Foggy and misty street", "Eerie abandoned hospital", "Desolate and ruined church", "Haunted hotel room", "Sinister carnival or amusement park", "Mysterious and ominous cave system", "Spooky old attic or basement", "Haunted cornfield or farmstead", "Creepy abandoned carnival", "Shadowy and ominous swamp", "Ethereal and ghostly foggy moorland", "Mysterious and dark library", "Haunted abandoned school", "Spooky and dark circus tent", "Eerie abandoned laboratory", "Sinister abandoned factory or warehouse", "Creepy and isolated island", "Haunted abandoned ship or ghostly shipwreck", "Mysterious and foreboding mountain pass", "Spooky and dimly lit catacombs or tombs"]
    hand_gestures = ["Thumbs up", "Thumbs down", "Peace sign", "OK sign", "Fist bump", "High five", "Waving", "Handshake", "Crossing fingers", "Pointing", "Shaka sign", "Horns sign", "Clapping", "Finger guns", "Making a heart shape with your hands", "Air quotes", "Salute", "Prayer", "Rocker sign", "Masonic hand gestures", "Thumb and pinky finger extended", "Finger tapping", "Pinching gesture", "The 'OK' gesture made by circling thumb and forefinger", "The 'A-OK' gesture made by making a circle with thumb and forefinger and holding the remaining fingers up"]
    
    attributes = {
        'Name': random_nft_name(),
        'Hair': random.choice(hair),
        'ghostly_clothing_styles': random.choice(ghostly_clothing_styles),
        'Animal': random_element(animals, 10),
        'Color': random.choice(color),
        'Hand_Gesture': random_element(hand_gestures, 12),
        'Persona': random.choice(persona),
        'Highlight': random_element(supernatural_highlights, 10),
        'Glamour': random_element(ghostly_glamor, 2),
        'Background': random.choice(spooky_background),
        
        'STR': random.randint(3, 18),
        'DEX': random.randint(3, 18),
        'INT': random.randint(3, 18),
        'WIS': random.randint(3, 18),
        'PSY': (random.randint(3, 18)+3),
        'CHA': random.randint(3, 18),
    }

    return attributes

def generate_prompt(attributes):
    prompt_parts = ['A high-resolution,4K photo-realistic portrait of a translucent ghost young woman, view should be centered on the womans detailed facial features, dramatic pose, gloomy dynamic lighting']

    for key, value in attributes.items():
        if value is not None and key != 'Name':
            prompt_parts.append('a {} of {} '.format(key, value))

    prompt = ' '.join(prompt_parts)
    # prompt = prompt[:-1] + ' on the background of a {}.'.format(attributes['environmentBG'])
    return prompt

def generate_image(prompt):
    response = openai.Image.create(
        #model="image-alpha-001",
        prompt=prompt,
        n=1,
        size="512x512",
        response_format="url"
    )

    image_url = response["data"][0]["url"]
    return image_url

def add_file_to_ipfs(file_path):
    with ipfshttpclient.connect() as client:
        result = client.add(file_path)
        return result

def save_metadata(attributes, metadata_path, asset_cidcombo):
    # Define the metadata dictionary
    metadata = {
        "Series": f"{series_data} NFT",
        "Description": description,
        "image": f"ipfs://{asset_cidcombo}"        
    }

    # Add the attributes from the 'attributes' dictionary to the metadata dictionary
    for key, value in attributes.items():
        metadata[key] = value

    # Open the metadata file for writing
    with open(metadata_path, "w") as f:
        # Write the metadata dictionary to the file as JSON
        json.dump(metadata, f)

    # Return the metadata dictionary
    return metadata
        
if __name__ == '__main__':
    
    
    a = 0
    while a < int(quantity):
        # Generate the NFT character and attributes
        attributes = generate_nft_character()

        # Generate the text prompt
        prompt = generate_prompt(attributes)

        # Call the function with the prompt
        image_url = generate_image(prompt)
    

        # Use this image_url to download and save the image or display it in your application
        print(image_url)
        print(prompt)
    
        # Save the image and metadata locally
        nft_id = random.randint(1, 1000000)  # Generate a random unique identifier
        image_path = f'images/nft_{nft_id}.png'
        metadata_path = f'metadata/nft_{nft_id}.json'
        asset_cidcombo = f'{asset_cid}/nft_{nft_id}.png'
        
        save_image(image_url, image_path)
        save_metadata(attributes, metadata_path, asset_cidcombo)

        # Add the image and metadata to IPFS
        image_ipfs_result = add_file_to_ipfs(image_path)
        metadata_ipfs_result = add_file_to_ipfs(metadata_path)

        # Get the IPFS hashes
        image_ipfs_hash = image_ipfs_result['Hash']
        metadata_ipfs_hash = metadata_ipfs_result['Hash']

        print(f"Image IPFS hash: {image_ipfs_hash}")
        print(f"Metadata IPFS hash: {metadata_ipfs_hash}")
        
        time.sleep(2) 
        
        a += 1
# Out:
# Enter the series data for your NFT: test3
# Enter a description for your NFT: test
# Enter the IPFS CID for your NFT asset: QmSfVPPQNcCxdweLXGwRSHomF7qgvHphnnZGnqvky5URYR
# Enter the quantity you want to make: 5
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-51ewe0KKfOYW12fuVvXCbgnq/user-2ITlbk3YrlIeR5M8hk8x3BVv/img-4IGTWmdHHhe3yP7i0lbz24PU.png?st=2023-03-21T02%3A18%3A28Z&se=2023-03-21T04%3A18%3A28Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-20T20%3A36%3A09Z&ske=2023-03-21T20%3A36%3A09Z&sks=b&skv=2021-08-06&sig=C0Xj6ILbwKiTlIcxz2hBhpL%2BJoLKgmpAsdAvIFuNFzU%3D
# ...
