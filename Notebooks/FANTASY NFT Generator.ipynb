# %%
#  SCi fi NFT image and json creator.  This will run the creator 10 times.

import os
import json
import random
import openai
import ipfshttpclient
from PIL import Image, ImageDraw
import requests
from io import BytesIO

openai.api_key = "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"

series_data = input("Enter the series data for your NFT: ")
description = input("Enter a description for your NFT: ")
asset_cid = input("Enter the IPFS CID for your NFT asset: ")
quantity = input("Enter the quantity you want to make: ")


if not os.path.exists('images001'):
    os.makedirs('images001')

if not os.path.exists('metadata001'):
    os.makedirs('metadata001')
    
    
def random_element(elements, rarity):
    if random.random() <= rarity / 100:
        return random.choice(elements)
    else:
        return None

def save_image(image_url, image_path):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    image.save(image_path)

def generate_scifi_name():
    syllables = ["al", "ar", "ba", "be", "ca", "ce", "da", "de", "el", "en", "fa", "fi", "fo", "ga", "gi", "he", "ho", "in", "io", "ja", "jo", "ka", "ki", "la", "le", "ma", "mi", "na", "nu", "ol", "or", "pa", "po", "qu", "ra", "re", "sa", "ta", "ul", "ve", "va", "we", "xo", "xi", "ye", "yo", "ze", "za"]
    name_length = random.randint(2, 4)
    name = ''
    
    for i in range(name_length):
        name += random.choice(syllables)
        
    return name.capitalize()
def generate_fantasy_title():
    adjectives = ["Mystical", "Enchanted", "Whimsical", "Magical", "Ethereal", "Legendary", "Mythical", "Radiant", "Divine", "Arcane", "Otherworldly", "Enigmatic", "Pristine", "Celestial", "Iridescent", "Supernatural", "Phantasmal", "Spectral", "Chimerical", "Elysian", "Fabled", "Fantastic", "Illustrious", "Imaginary", "Miraculous"]
    nouns = ["Sorcerer", "Wizard", "Enchanter", "Magician", "Oracle", "Prophet", "Mystic", "Seer", "Champion", "Hero", "Warrior", "Knight", "Paladin", "Gladiator", "Adventurer", "Explorer", "Treasure Hunter", "Dragon Slayer", "Monster Hunter", "Fairy", "Nymph", "Dryad", "Elf", "Dwarf", "Gnome", "Troll", "Ogre", "Goblin", "Siren"]
    name = ' '.join([random.choice(adjectives), random.choice(nouns)])
    return name

def generate_fantasy_location():
    adjectives = ["Mystical", "Enchanted", "Whimsical", "Magical", "Ethereal", "Legendary", "Mythical", "Radiant", "Divine", "Arcane", "Otherworldly", "Enigmatic", "Pristine", "Celestial", "Iridescent", "Supernatural", "Phantasmal", "Spectral", "Chimerical", "Elysian", "Fabled", "Fantastic", "Illustrious", "Imaginary", "Miraculous"]
    nouns = ["Land", "Kingdom", "Empire", "Realm", "Nation", "Territory", "Domain", "Province", "State", "Colony", "City", "Village", "Town", "Outpost", "Stronghold", "Castle", "Fortress", "Tower", "Keep", "Palace", "Haven", "Sanctuary", "Shrine", "Temple", "Grotto", "Cavern", "Chamber", "Lair", "Tomb", "Ruin", "Mine", "Forest", "Jungle", "Desert", "Swamp", "Tundra", "Mountain", "Volcano", "Island", "Ocean", "Sea", "River", "Lake"]
    name = ' '.join([random.choice(adjectives), random.choice(nouns)])
    return name

def random_nft_name():
    title = generate_fantasy_title()
    location = generate_fantasy_location()
    return f'{title} of the {location}'

def generate_nft_character():
    base_prompt = 'hyper-realistic image of Fantsy girl in dramatic action pose'
    hats = ["Wizard hat", "Knight's helm", "Enchanted tiara", "Dragon scale cap", "Fairy crown", "Pirate tricorne", "Elven circlet", "Dwarven helm", "Necromancer hood", "Magician's top hat", "Mermaid headband", "Phoenix feather headdress", "Goblin cap", "Cyclops eye patch", "Gnome pointy hat", "Sorcerer's turban", "Unicorn horn headband", "Orc war helm", "Angel halo", "Demon horns"]
    hair = ["Short and spiky", "Cropped and neat", "Chin-length bob", "Long and straight", "Curly and voluminous", "Wavy and shoulder-length", "Pixie cut", "Shaved sides with long top", "Sleek ponytail", "Messy bun", "Half-up half-down", "Braided crown", "French braid", "Cornrows", "Dreadlocks", "Fishtail braid", "Top knot", "Ballerina bun", "Braid-out", "Afro"]
    animals = ["Dragon", "Unicorn", "Phoenix", "Griffin", "Pegasus", "Sphinx", "Chimera", "Cerberus", "Basilisk", "Kraken", "Minotaur", "Centaur", "Gorgon", "Manticore", "Hydra", "Hippogriff", "Satyr", "Fenrir", "Siren", "Werewolf"]

    colors = ["Sapphire blue", "Emerald green", "Ruby red", "Amethyst purple", "Gold", "Silver", "Bronze", "Crimson", "Indigo", "Rose pink", "Onyx black", "Pearl white", "Topaz yellow", "Jade green", "Opal iridescent", "Garnet red", "Turquoise", "Peridot green", "Aquamarine blue", "Citrine yellow"]

    weapon = ["Staff of power", "Sword of destiny", "Bow of the huntress", "Axe of the berserker", "Dagger of the assassin", "Mace of the crusader", "Hammer of thunder", "Spear of the conqueror", "Flail of the fallen", "Wand of enchantment", "Trident of the sea", "Chakram of the warrior", "Glaive of the defender", "Whip of the serpent", "Nunchaku of the monk", "Halberd of the sentinel", "Scythe of the reaper", "Crossbow of the marksman", "Shuriken of the ninja", "Pistol of the gunslinger"]

    persona = ["Sorceress", "Knight", "Assassin", "Druid", "Barbarian", "Ranger", "Priestess", "Paladin", "Bard", "Thief", "Necromancer", "Warlock", "Monk", "Shaman", "Alchemist", "Martial artist", "Summoner", "Gladiator", "Pirate", "Vampire"]

    magic = ["Elemental magic", "Divine magic", "Necromancy", "Illusion magic", "Enchantment magic", "Nature magic", "Shadow magic", "Blood magic", "Time magic", "Alchemy", "Chaos magic", "Frost magic", "Fire magic", "Lightning magic", "Celestial magic", "Demon magic", "Dragon magic", "Artifice magic", "Dream magic", "Spirit magic"]

    glamour = ["Elven beauty", "Dwarven craftsmanship", "Fairy glamour", "Mermaid enchantment", "Phoenix radiance", "Goblin trickery", "Nymph allure", "Siren song", "Succubus seduction", "Angelic purity", "Demon corruption", "Vampire allure", "Werewolf ferocity", "Undead terror", "Gargoyle fortitude", "Dragon majesty", "Giant strength", "Gnome ingenuity", "Cyclops strength", "Gnome ingenuity", "Cyclops brawn", "Satyr revelry"]

    background = ["Enchanted forest", "Magical academy", "Dragon's lair", "Underwater kingdom", "Fairy kingdom", "Haunted castle", "Dark underworld", "Celestial realm", "Desolate wasteland", "Volcanic mountain", "Mystical garden", "Frozen tundra", "Shadowy alleyways", "Ancient ruins", "Mystical library", "Giant's kingdom", "Feywilds", "Cloud city", "Mysterious island", "Witch's coven"]
    
           
           
           
    attributes = {
        'Name': random_nft_name(),
        'Hair': random.choice(hair),
        'Hat': random_element(hats, 20),
        'Animal': random_element(animals, 10),
        'Color': random.choice(colors),
        'Weapon': random_element(weapon, 25),
        'Persona': random.choice(persona),
        'Magick': random_element(magic, 10),
        'Glamour': random_element(glamour, 2),
        'Background': random.choice(background),
    }

    return attributes

def generate_prompt(attributes):
    prompt_parts = ['4k photo-realistic portrait of a Fantasy girl, detailed facial features, dramatic pose, dynamic lighting']

    for key, value in attributes.items():
        if value is not None and key != 'Name':
            prompt_parts.append('with a {} of {} '.format(key, value))

    prompt = ' '.join(prompt_parts)
    # prompt = prompt[:-1] + ' on the background of a {}.'.format(attributes['environmentBG'])
    return prompt

def generate_image(prompt):
    response = openai.Image.create(
        #model="image-alpha-001",
        prompt=prompt,
        n=1,
        size="512x512",
        response_format="url",
    )

    image_url = response["data"][0]["url"]
    return image_url

def add_file_to_ipfs(file_path):
    with ipfshttpclient.connect() as client:
        result = client.add(file_path)
        return result

def save_metadata(attributes, metadata_path, asset_cidcombo):
    # Define the metadata dictionary
    metadata = {
        "Series": f"{series_data} NFT",
        "Description": description,
        "image": f"ipfs://{asset_cidcombo}"        
    }

    # Add the attributes from the 'attributes' dictionary to the metadata dictionary
    for key, value in attributes.items():
        metadata[key] = value

    # Open the metadata file for writing
    with open(metadata_path, "w") as f:
        # Write the metadata dictionary to the file as JSON
        json.dump(metadata, f)

    # Return the metadata dictionary
    return metadata
        
if __name__ == '__main__':
    
    
    a = 0
    while a < int(quantity):
        # Generate the NFT character and attributes
        attributes = generate_nft_character()

        # Generate the text prompt
        prompt = generate_prompt(attributes)

        # Call the function with the prompt
        image_url = generate_image(prompt)
    

        # Use this image_url to download and save the image or display it in your application
        print(image_url)
        print(prompt)
    
         # Save the image and metadata locally
        nft_id = random.randint(1, 1000000)  # Generate a random unique identifier
        image_path = f'images001/nft_{nft_id}.png'
        metadata_path = f'metadata001/nft_{nft_id}.json'
        asset_cidcombo = f'{asset_cid}/nft_{nft_id}.png'
        
        save_image(image_url, image_path)
        save_metadata(attributes, metadata_path, asset_cidcombo)

        # Add the image and metadata to IPFS
        image_ipfs_result = add_file_to_ipfs(image_path)
        metadata_ipfs_result = add_file_to_ipfs(metadata_path)

        # Get the IPFS hashes
        image_ipfs_hash = image_ipfs_result['Hash']
        metadata_ipfs_hash = metadata_ipfs_result['Hash']

        print(f"Image IPFS hash: {image_ipfs_hash}")
        print(f"Metadata IPFS hash: {metadata_ipfs_hash}")
        
        a += 1
        
    
print("Process Finished.")
# Out:
# Enter the series data for your NFT: Fantasy Series 001
# Enter a description for your NFT: A collection of fantasy characters
# Enter the IPFS CID for your NFT asset: QmUNLLsPACCz1vLxQVkXqqLX5R1X345qqfHbsf67hvA3Nn
# Enter the quantity you want to make: 10
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-51ewe0KKfOYW12fuVvXCbgnq/user-2ITlbk3YrlIeR5M8hk8x3BVv/img-Tzl95383o45sikUMXAUSd83j.png?st=2023-03-20T00%3A25%3A02Z&se=2023-03-20T02%3A25%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-20T01%3A15%3A53Z&ske=2023-03-21T01%3A15%3A53Z&sks=b&skv=2021-08-06&sig=wtTFTGD4Tx0QC8DQT/NRUloSIgHtKpWN9MoGIBDECCM%3D
# 4k photo-realistic portrait of a Fantasy girl, detailed facial features, dramatic pose, dynamic lighting with a Hair of Messy bun  with a Color of Emerald green  with a Persona of Pirate  with a Background of Celestial realm
# ...

# %%
import random

def generate_fantasy_title():
    adjectives = ["Mystical", "Enchanted", "Whimsical", "Magical", "Ethereal", "Legendary", "Mythical", "Radiant", "Divine", "Arcane", "Otherworldly", "Enigmatic", "Pristine", "Celestial", "Iridescent", "Supernatural", "Phantasmal", "Spectral", "Chimerical", "Elysian", "Fabled", "Fantastic", "Illustrious", "Imaginary", "Miraculous"]
    nouns = ["Sorcerer", "Wizard", "Enchanter", "Magician", "Oracle", "Prophet", "Mystic", "Seer", "Champion", "Hero", "Warrior", "Knight", "Paladin", "Gladiator", "Adventurer", "Explorer", "Treasure Hunter", "Dragon Slayer", "Monster Hunter", "Fairy", "Nymph", "Dryad", "Elf", "Dwarf", "Gnome", "Troll", "Ogre", "Goblin", "Siren", "Mermaid", "Kraken", "Phoenix", "Griffin", "Centaur", "Minotaur", "Unicorn", "Pegasus", "Basilisk", "Gorgon", "Hydra", "Cerberus", "Chimera"]
    name = ' '.join([random.choice(adjectives), random.choice(nouns)])
    return name

def generate_fantasy_location():
    adjectives = ["Mystical", "Enchanted", "Whimsical", "Magical", "Ethereal", "Legendary", "Mythical", "Radiant", "Divine", "Arcane", "Otherworldly", "Enigmatic", "Pristine", "Celestial", "Iridescent", "Supernatural", "Phantasmal", "Spectral", "Chimerical", "Elysian", "Fabled", "Fantastic", "Illustrious", "Imaginary", "Miraculous"]
    nouns = ["Land", "Kingdom", "Empire", "Realm", "Nation", "Territory", "Domain", "Province", "State", "Colony", "City", "Village", "Town", "Outpost", "Stronghold", "Castle", "Fortress", "Tower", "Keep", "Palace", "Haven", "Sanctuary", "Shrine", "Temple", "Grotto", "Cavern", "Chamber", "Lair", "Tomb", "Ruin", "Mine", "Forest", "Jungle", "Desert", "Swamp", "Tundra", "Mountain", "Volcano", "Island", "Ocean", "Sea", "River", "Lake"]
    name = ' '.join([random.choice(adjectives), random.choice(nouns)])
    return name

def random_nft_name():
    title = generate_fantasy_title()
    location = generate_fantasy_location()
    return f'{title} of {location}'

a=1
while a<20:
    print(random_nft_name())
    a += 1
# Out:
# Fabled Champion of Celestial Swamp
# Enchanted Griffin of Otherworldly Ruin
# Illustrious Goblin of Ethereal Swamp
# Fantastic Prophet of Fantastic Mine
# Miraculous Wizard of Arcane State
# Ethereal Enchanter of Enigmatic Province
# Pristine Dwarf of Chimerical Nation
# Elysian Seer of Enigmatic Lair
# Celestial Seer of Fantastic Haven
# Miraculous Mystic of Spectral Sea
# Pristine Magician of Celestial Realm
# Magical Unicorn of Otherworldly Ruin
# Fantastic Enchanter of Chimerical Mountain
# Mythical Dragon Slayer of Mythical Tomb
# Enigmatic Hydra of Ethereal Lair
# Imaginary Hero of Fantastic Land
# Fantastic Troll of Elysian Desert
# Elysian Kraken of Mythical Fortress
# Legendary Centaur of Fabled Desert
