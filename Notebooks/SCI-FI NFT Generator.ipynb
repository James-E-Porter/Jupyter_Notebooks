# %%
#  SCi fi NFT image and json creator.  This will run the creator 10 times.

import os
import json
import random
import openai
import ipfshttpclient
from PIL import Image, ImageDraw
import requests
from io import BytesIO
import time
from pathlib import Path


openai.api_key = "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"

series_data = input("Enter the series data for your NFT: ")
description = input("Enter a description for your NFT: ")
quantity = input("Enter the quantity you want to make: ")


if not os.path.exists('images'):
    os.makedirs('images')

if not os.path.exists('metadata'):
    os.makedirs('metadata')
    
    
def random_element(elements, rarity):
    if random.random() <= rarity / 100:
        return random.choice(elements)
    else:
        return None

def generate_scifi_name():
    syllables = ["al", "ar", "ba", "be", "ca", "ce", "da", "de", "el", "en", "fa", "fi", "fo", "ga", "gi", "he", "ho", "in", "io", "ja", "jo", "ka", "ki", "la", "le", "ma", "mi", "na", "nu", "ol", "or", "pa", "po", "qu", "ra", "re", "sa", "ta", "ul", "ve", "va", "we", "xo", "xi", "ye", "yo", "ze", "za"]
    name_length = random.randint(2, 4)
    global name
    name = ''
    
    for i in range(name_length):
        name += random.choice(syllables)
        
    return name.capitalize()

def random_nft_name():
    adjectives = ["Neon", "Cyber", "Galactic", "Quantum", "Astro", "Cosmic", "Nebula", "Plasma", "Vortex", "Exo", "Interstellar", "Futuristic", "Cybernetic", "Alien", "Hyperdrive", "Nano", "Robotic", "Exoplanetary", "Cosmo", "Intergalactic", "Orbital", "Hyperspace", "Transdimensional", "Astral", "Celestial", "Ethereal", "Metaphysical", "Multidimensional", "Paradoxical"]
    nouns = ["Android", "Cyborg", "Clone", "AI", "Robot", "Mutant", "Alien", "Mechanic", "Pilot", "Captain", "Commander", "Mercenary", "Bounty Hunter", "Assassin", "Explorer", "Agent", "Scientist", "Engineer", "Hacker", "Smuggler", "Warrior", "Guardian", "Sentinel", "Spacer", "Navigator", "Teleporter", "Xenobiologist", "Time Traveler", "Colonist", "Survivor"]
    name = generate_scifi_name()
    return f'{random.choice(adjectives)} {random.choice(nouns)} {name}'
    
def generate_nft_character():
    base_prompt = 'hyper-realistic image of sci-fi girl in dramatic action pose with cyber tones'
    hair = ["Short and spiky", "Cropped and neat", "Chin-length bob", "Long and straight", "Curly and voluminous", "Wavy and shoulder-length", "Pixie cut", "Shaved sides with long top", "Sleek ponytail", "Messy bun", "Half-up half-down", "Braided crown", "French braid", "Cornrows", "Dreadlocks", "Fishtail braid", "Top knot", "Ballerina bun", "Braid-out", "Afro"]
    hats = ["fedora", "baseball cap", "top hat", "beanie", "bowler hat", "beret", "bucket hat", "cowboy hat", "sombrero", "snapback hat", "trucker hat", "flat cap", "newsboy cap", "visor", "crown", "chef's hat", "pith helmet", "fascinator", "tam o'shanter", "ushanka"]
    sunglasses = ["aviator glasses", "wayfarer glasses", "round glasses", "rectangle glasses", "cat-eye glasses", "browline glasses", "pince-nez glasses", "rimless glasses", "half-rim glasses", "oversized glasses", "sport glasses", "goggles", "monocle"]
    animals = ["axolotl", "quokka", "blobfish", "fossa", "okapi", "narwhal", "maned wolf", "tarsier", "aardvark", "sugar glider", "platypus", "pink fairy armadillo", "sloth", "hoatzin", "mantaray", "vampire squid", "chimaera", "flying fish", "frilled shark", "colugo"]
    color = ["beige", "cream", "off-white", "ivory", "champagne", "peach", "coral", "salmon", "pink", "rose", "lavender", "lilac", "mauve", "violet", "purple", "plum", "indigo", "navy", "teal", "turquoise", "sky blue", "baby blue", "cornflower blue", "royal blue", "cobalt blue", "navy blue", "steel blue", "mint green", "sage green", "olive green", "emerald green", "lime green", "forest green", "khaki", "camel", "goldenrod", "mustard", "ochre", "burnt orange", "rust", "terracotta", "brick red", "burgundy", "maroon", "taupe", "gray", "charcoal", "black", "white"]
    lasers = ["red laser", "green laser", "blue laser", "purple laser", "yellow laser", "UV laser", "infrared laser", "fiber laser", "solid-state laser", "gas laser", "chemical laser", "free-electron laser", "dye laser", "excimer laser", "co2 laser", "pulsed laser", "continuous wave laser", "diode laser", "helium-neon laser", "argon laser", "krypton laser", "xenon laser", "carbon-dioxide laser", "neodymium-doped yttrium aluminum garnet laser", "ruby laser"]
    weapons = ["phaser pistols", "blaster pistols", "plasma pistols", "ion blasters", "laser pistols", "disruptor pistols", "neural disruptors", "gravity grenades", "shockwave pistols", "sonic disruptor pistols", "teleportation devices", "nano-knives", "force field generators", "molecular disruptor pistols", "ion disruptor pistols", "psychic amplifying devices", "cloaking devices", "time disruptor pistols", "energy shields", "plasma swords"]
    persona = ["androids", "cyborgs", "artificial intelligences", "mutants", "cybercriminals", "hackers", "rebels", "clones", "space marines", "space pirates", "explorers", "bounty hunters", "mercenaries", "smugglers", "spies", "assassins", "diplomats", "scientists", "engineers", "soldiers", "pilots", "freedom fighters", "aliens", "time travelers", "interdimensional beings", "psychics", "mutineers", 'soldier', 'pilot', 'waifu', 'street urchin', 'punk', 'pirate', 'villainess', 'villain', 'evil', 'good', 'wizard', 'sorceror', 'psychic', 'android', 'psi-ops', 'assasin', 'diva', 'princess', 'citizen', 'hooligan']
    digital_highlights = ["holographic displays", "cybernetic implants", "virtual reality interfaces", "artificial intelligence assistants", "neural implants", "cyberspace networks", "augmented reality overlays", "brain-computer interfaces", "nanomachines", "quantum computers", "cybersecurity measures", "encryption algorithms", "neural networks", "artificial lifeforms", "data visualization tools", "machine learning algorithms", "cyber warfare tactics", "cyber-enhanced weaponry", "neural simulations", "virtual assistants", "artificial reality systems", "cybernetic avatars", "biometric security systems", "quantum encryption"]
    glamor = ["cyberpunk fashion", "futuristic hairstyles", "luminous body paint", "elaborate cybernetic enhancements", "neon lighting effects", "hovering vehicles", "glowing tattoos", "exotic space jewelry", "metallic fabrics", "cosmic makeup", "advanced prosthetics", "incredible special effects", "futuristic architecture", "holographic billboards", "colorful bioluminescent flora", "levitating cities", "floating space stations", "incredible cybernetic landscapes", "futuristic weapon designs", "high-tech gadgets", "radical alien designs", "cyber-enhanced pets", "intergalactic fashion shows", "digital fireworks"]
    background = ["neon-lit futuristic cityscape", "towering skyscrapers", "holographic advertisements",
        "underground cyberpunk bunker", "dim lighting", "flickering computer screens",
        "virtual reality simulation", "bright colors", "geometric shapes",
        "dark and shadowy industrial complex", "machinery", "cables",
        "sleek and futuristic spaceship interior", "advanced technology", "glowing control panels",
        "post-apocalyptic wasteland", "ruined buildings", "scavenged cybernetic enhancements",
        "digital world", "endless circuits", "glowing neon lines stretching to infinity",
        "high-tech laboratory", "glowing test tubes", "advanced equipment",
        "sleek and minimalist smart home", "advanced automation", "digital interfaces",
        "virtual reality gaming arena", "neon lights", "holographic projections"]
    
    attributes = {
        'Name': random_nft_name(),
        'Hair': random.choice(hair),
        'Hat': random_element(hats, 20),
        'Sunglasses': random_element(sunglasses, 10),
        'Animal': random_element(animals, 10),
        'Color': random.choice(color),
        'Laser': random_element(lasers, 20),
        'Weapon': random_element(weapons, 25),
        'Persona': random.choice(persona),
        'Highlight': random_element(digital_highlights, 10),
        'Glamour': random_element(glamor, 2),
        'Background': random.choice(background),
    }

    return attributes

def generate_prompt(attributes):
    prompt_parts = ['A high-resolution,4K photo-realistic portrait of a sci-fi muppet show muppet detailed facial features, dramatic pose, dynamic lighting']

    for key, value in attributes.items():
        if value is not None and key != 'Name':
            prompt_parts.append('a {} of {} '.format(key, value))

    prompt = ' '.join(prompt_parts)
    # prompt = prompt[:-1] + ' on the background of a {}.'.format(attributes['environmentBG'])
    return prompt

def generate_image(prompt):
    response = openai.Image.create(
        #model="image-alpha-001",
        prompt=prompt,
        n=1,
        size="512x512",
        response_format="url"
    )

    image_url = response["data"][0]["url"]
    return image_url

def add_image_to_ipfs(file_name):
    with ipfshttpclient.connect() as client:
        result = client.add(file_name)
        return result

def add_meta_to_ipfs(meta_name):
    with ipfshttpclient.connect() as client:
        result = client.add(meta_name)
        return result

def save_image(image_url, image_path):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    image.save(image_path)
    
def save_metadata(attributes, metadata_path, image_ipfs_result):
    # Define the metadata dictionary
    metadata = {
        "Series": f"{series_data} NFT",
        "Description": description,
        "image": f"ipfs://{image_ipfs_result['Hash']}/nft_{name}.png"        
    }

    # Add the attributes from the 'attributes' dictionary to the metadata dictionary
    for key, value in attributes.items():
        metadata[key] = value

    # Open the metadata file for writing
    with open(metadata_path, "w") as f:
        # Write the metadata dictionary to the file as JSON
        json.dump(metadata, f)

    # Return the metadata dictionary
    return metadata
        
if __name__ == '__main__':
    
    
    a = 0
    while a < int(quantity):
        # Generate the NFT character and attributes
        attributes = generate_nft_character()

        # Generate the text prompt
        prompt = generate_prompt(attributes)

        # Call the function with the prompt
        image_url = generate_image(prompt)
    

        # Use this image_url to download and save the image or display it in your application
        print(image_url)
        print(prompt)
    
        # Save the image  locally
        global file_name
        file_name = f'nft_{name}.png'
        global meta_name
        meta_name =f'nft_{name}.json'
        image_path = f'nft_{name}.png'
        metadata_path = f'nft_{name}.json'
        
        save_image(image_url, image_path)
        
        # Save the image file to IPFS
        image_ipfs_result = add_image_to_ipfs(image_path)
        
        # Create metadata
        save_metadata(attributes, metadata_path, image_ipfs_result)

        # Add the image and metadata to IPFS
        image_ipfs_result = add_image_to_ipfs(file_name)
        metadata_ipfs_result = add_meta_to_ipfs(meta_name)

        # Get the IPFS hashes
        image_ipfs_hash = image_ipfs_result['Hash']
        metadata_ipfs_hash = metadata_ipfs_result['Hash']

        print(f"Image IPFS hash: {image_ipfs_hash}")
        print(f"Metadata IPFS hash: {metadata_ipfs_hash}")
        
        time.sleep(2) 
        
        a += 1
# Out:
# Enter the series data for your NFT: dhdh
# Enter a description for your NFT: glgl
# Enter the quantity you want to make: 4
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-51ewe0KKfOYW12fuVvXCbgnq/user-2ITlbk3YrlIeR5M8hk8x3BVv/img-vIM7xFMHzVnaGCOaVQMc3Ave.png?st=2023-03-23T01%3A39%3A08Z&se=2023-03-23T03%3A39%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-23T02%3A20%3A26Z&ske=2023-03-24T02%3A20%3A26Z&sks=b&skv=2021-08-06&sig=%2BDgN23E/aNadq0HBU59l%2BwQeKFU9nIk3vfMrR1WnSD4%3D
# A high-resolution,4K photo-realistic portrait of a sci-fi muppet show muppet detailed facial features, dramatic pose, dynamic lighting a Hair of Messy bun  a Color of salmon  a Weapon of shockwave pistols  a Persona of citizen  a Highlight of cyber warfare tactics  a Background of high-tech laboratory
# Image IPFS hash: QmcahkzUYTqQcNmMfFutDBtKtH6FWfc93tMjsov1sKsE2y
# ...

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-51ewe0KKfOYW12fuVvXCbgnq/user-2ITlbk3YrlIeR5M8hk8x3BVv/img-3kRLliKrr5ltpJKJD7hYmLxI.png?st=2023-03-21T19%3A46%3A30Z&se=2023-03-21T21%3A46%3A30Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-03-21T15%3A53%3A57Z&ske=2023-03-22T15%3A53%3A57Z&sks=b&skv=2021-08-06&sig=AJ7IzzqXOzFZ8gs86h0Rs3oZQUFK6EmuaPfebtF4aUY%3D'

# %%
import random

a=1
while a<20:
    def generate_scifi_name():
        syllables = ["al", "ar", "ba", "be", "ca", "ce", "da", "de", "el", "en", "fa", "fi", "fo", "ga", "gi", "he", "ho", "in", "io", "ja", "jo", "ka", "ki", "la", "le", "ma", "mi", "na", "nu", "ol", "or", "pa", "po", "qu", "ra", "re", "sa", "ta", "ul", "ve", "va", "we", "xo", "xi", "ye", "yo", "ze", "za"]
        name_length = random.randint(2, 4)
        name = ''
    
        for i in range(name_length):
            name += random.choice(syllables)
        
        return name.capitalize()

    def random_nft_name():
        adjectives = ["Neon", "Cyber", "Galactic", "Quantum", "Astro", "Cosmic", "Nebula", "Plasma", "Vortex", "Exo", "Interstellar", "Futuristic", "Cybernetic", "Alien", "Hyperdrive", "Nano", "Robotic", "Exoplanetary", "Cosmo", "Intergalactic", "Orbital", "Hyperspace", "Transdimensional", "Astral", "Celestial", "Ethereal", "Metaphysical", "Multidimensional", "Paradoxical"]
        nouns = ["Android", "Cyborg", "Clone", "AI", "Robot", "Mutant", "Alien", "Mechanic", "Pilot", "Captain", "Commander", "Mercenary", "Bounty Hunter", "Assassin", "Explorer", "Agent", "Scientist", "Engineer", "Hacker", "Smuggler", "Warrior", "Guardian", "Sentinel", "Spacer", "Navigator", "Teleporter", "Xenobiologist", "Time Traveler", "Colonist", "Survivor"]
        name = generate_scifi_name()
        return f'{random.choice(adjectives)} {random.choice(nouns)} {name}'

    print(random_nft_name())
    
    a += 1
# Out:
# Nano Spacer Xoweyesa
# Galactic Explorer Iomacaqu
# Interstellar Navigator Yepafinu
# Multidimensional Commander Xitamare
# Plasma Warrior Arfa
# Astral Xenobiologist Nuolin
# Astro Survivor Tanaxior
# Vortex Spacer Wehoja
# Interstellar Pilot Fade
# Futuristic Mercenary Giweenwe
# Robotic Explorer Cayoyo
# Ethereal Warrior Rezakayo
# Metaphysical Warrior Bale
# Astro Scientist Zanujada
# Exoplanetary Scientist Lagida
# Hyperdrive Android Saminu
# Quantum Hacker Jaulorba
# Hyperspace Sentinel Kaolenye
# Exoplanetary Guardian Quhode

# %%
import random

def generate_fantasy_title():
    adjectives = ["Mystical", "Enchanted", "Whimsical", "Magical", "Ethereal", "Legendary", "Mythical", "Radiant", "Divine", "Arcane", "Otherworldly", "Enigmatic", "Pristine", "Celestial", "Iridescent", "Supernatural", "Phantasmal", "Spectral", "Chimerical", "Elysian", "Fabled", "Fantastic", "Illustrious", "Imaginary", "Miraculous"]
    nouns = ["Sorcerer", "Wizard", "Enchanter", "Magician", "Oracle", "Prophet", "Mystic", "Seer", "Champion", "Hero", "Warrior", "Knight", "Paladin", "Gladiator", "Adventurer", "Explorer", "Treasure Hunter", "Dragon Slayer", "Monster Hunter", "Fairy", "Nymph", "Dryad", "Elf", "Dwarf", "Gnome", "Troll", "Ogre", "Goblin", "Siren", "Mermaid", "Kraken", "Phoenix", "Griffin", "Centaur", "Minotaur", "Unicorn", "Pegasus", "Basilisk", "Gorgon", "Hydra", "Cerberus", "Chimera"]
    name = ' '.join([random.choice(adjectives), random.choice(nouns)])
    return name

def random_nft_name():
    name = generate_fantasy_title()
    return f'{name} of {generate_scifi_name().capitalize()}'

a=1
while a<20:
    print(random_nft_name())
    a += 1
# Out:
# Ethereal Monster Hunter of Olar
# Pristine Dragon Slayer of Gahele
# Radiant Enchanter of Joxi
# Spectral Ogre of Nukire
# Chimerical Pegasus of Arca
# Celestial Sorcerer of Wenuwe
# Spectral Nymph of Dapa
# Phantasmal Griffin of Albaenqu
# Legendary Ogre of Hetain
# Ethereal Nymph of Engifoca
# Phantasmal Enchanter of Faba
# Enigmatic Ogre of Arna
# Otherworldly Prophet of Kamaxoxi
# Spectral Sorcerer of Joyeinfo
# Miraculous Monster Hunter of Xotava
# Arcane Troll of Pomaba
# Mythical Enchanter of Inel
# Divine Dryad of Ololga
# Mythical Mermaid of Deornu
